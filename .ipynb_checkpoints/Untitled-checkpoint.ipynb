# %%
import mlflow

# Step 2: Configure Tracking

# Option A: Database (Recommended)
mlflow.set_tracking_uri("sqlite:///mlflow.db")

# Option C: Remote Tracking Server
# mlflow.set_tracking_uri("http://localhost:5000")

mlflow.set_experiment("my-first-experiment")
# Out:
# <Experiment: artifact_location='/home/zelitosaide/Documents/mlops/mlruns/1', creation_time=1780664775064, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1780664775064, lifecycle_stage='active', name='my-first-experiment', tags={}, trace_location=None, workspace='default'>

# %%
# Step 3: Verify Your Connection
print(f"MLflow Tracking URI: {mlflow.get_tracking_uri()}")
print(f"Active Experiment: {mlflow.get_experiment_by_name('my-first-experiment')}")

import pandas as pd

house_price_data = pd.read_csv("./house_price_data.csv")

# # Test logging
# with mlflow.start_run():
#     mlflow.log_param("test_param", "test_value")
#     print("✓ Successfully connected to MLflow!")

# # Sem usa "with" seria assim:
# run = mlflow.start_run()

# try:
#     mlflow.log_param("test_param", "test_value")
#     print("✓ Successfully connected to MLflow!")
# finally:
#     mlflow.end_run()
# Out:
# MLflow Tracking URI: sqlite:///mlflow.db
# Active Experiment: <Experiment: artifact_location='/home/zelitosaide/Documents/mlops/mlruns/1', creation_time=1780664775064, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1780664775064, lifecycle_stage='active', name='my-first-experiment', tags={}, trace_location=None, workspace='default'>

# %%
house_price_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
house_price_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
house_price_data = house_price_data.dropna(axis=0)

# %%
house_price_data.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# ...

# %%
house_price_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Load the House price dataset
features = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude']
X = house_price_data[features].astype(float)
y = house_price_data["Price"]

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# Enable autologging for scikit-learn
mlflow.sklearn.autolog()

# Just train the model normally
house_price_lr_model = LinearRegression()
house_price_lr_model.fit(X_train, y_train)
# Out:
# 2026/06/09 15:39:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3e0087580976491ea1bcbf32b8404c8e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2026/06/09 15:39:28 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# LinearRegression()

# %%
predictions = house_price_lr_model.predict(X_test)

from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions, y_test)
# Out:
# 293237.74374876515

# %%
# from contextlib import contextmanager

# @contextmanager
# def greet():
#     yield "Ola, tudo bom?"

# with greet() as msg:
#     print(msg)
#     print("Estou bem")

# %%
# nova_msg = greet()

# try:
#     print(nova_msg)
#     print("EStou bem, obrigado")
# except:
#     print("Falhou")
# finally:
#     print("Fechando")

# %%
# Log a model and metadata manually

from sklearn.metrics import mean_absolute_error

# Start an MLflow run
with mlflow.start_run():
    # Train the model
    price_lr = LinearRegression()
    price_lr.fit(X_train, y_train)

    # Log the model
    model_info = mlflow.sklearn.log_model(sk_model=price_lr, name="zas_model_linear_regression")

    # Predict on the test set, compute and log the loss metrics
    y_pred = price_lr.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mlflow.log_metric("245_mae", mae)

    mlflow.set_tag("Training Info", "Basic LR model for house price data")
# Out:
# 2026/06/09 15:39:45 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/09 15:39:50 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html

# %%
# Load the model back for inference
# To load the model as a native scikiy-learn model, use
# mlflow.sklearn.load_model(model_info.model_uri) instead of the pyfunc flavor.
# Out:
# 'models:/m-7e5bf2455b7b4621a4cb5a0a34bac216'

# %%
# Load the model back for predictions as a generic Python Function model
loaded_model = mlflow.pyfunc.load_model(model_info.model_uri)
predictions = loaded_model.predict(X_test)

result = pd.DataFrame(X_test, columns=features)
result["Actual value"] = y_test
result["Predicted value"] = predictions
result[:4]

# OR
# loaded_model_2 = mlflow.sklearn.load_model(model_info.model_uri)
# predictions = loaded_model_2.predict(X_test)
# predictions
# Out:
#       Rooms  Bathroom  Landsize  BuildingArea  YearBuilt  Lattitude  \
# 6048    3.0       3.0     221.0         155.0     2011.0  -37.77080
# 9186    4.0       2.0     528.0         199.0     1980.0  -37.83539
# 3991    3.0       2.0       0.0         122.0     1998.0  -37.80950
# 5829    3.0       2.0    1039.0         133.0     2006.0  -37.86380
#
#       Longtitude  Actual value  Predicted value
# 6048    144.8401      620000.0     1.072047e+06
# 9186    145.0431     2320000.0     1.374924e+06
# 3991    144.9691      750000.0     9.198277e+05
# 5829    144.9820     1120000.0     9.897072e+05

# %%
# Tracking Hyperparameter Tuning with MLflow



# --------------------

# %%
import pandas as pd
from sklearn.datasets import fetch_openml

house_price_df = fetch_openml(
    "house_sales", version = 1, as_frame = True,
    return_X_y = False, parser = "auto"
)

house_price_df.data.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
house_price_df.data.drop(columns = ["date", "zipcode"], inplace = True)
house_price_df.data.sample(5)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 18339  372000.0         3       2.50         2430      5000     2.0
# 3763   598600.0         4       2.75         3470    212639     2.0
# 8813   580000.0         5       2.00         2600      3750     1.5
# 17247  696000.0         4       3.50         3650     38546     2.0
# 14273  685000.0         3       1.75         1650      8400     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 18339           0     0          3      8        2430              0
# 3763            0     0          3      7        2070           1400
# 8813            0     0          4      6        1400           1200
# 17247           0     0          3      9        2550           1100
# 14273           0     0          3      8        1470            180
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15
# ...

# %%
house_price_df.data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
house_price_df.data.shape
# Out:
# (21613, 18)

# %%
house_price_df.data = house_price_df.data.drop_duplicates()
house_price_df.data.shape
# Out:
# (21608, 18)

# %%
house_price_df.data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.160800e+04  21608.000000  21608.000000  21608.000000  2.160800e+04
# mean   5.400984e+05      3.370927      2.114738   2079.958950  1.510962e+04
# std    3.671646e+05      0.930103      0.770238    918.505805  4.142491e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.218375e+05      3.000000      1.750000   1429.250000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.620000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.069050e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21608.000000  21608.000000  21608.000000  21608.000000  21608.000000
# mean       1.494146      0.007544      0.234219      3.409478      7.656655
# ...

# %%
house_price_df.data["age"] = 2026 - house_price_df.data["yr_built"]
house_price_df.data["renovation_age"] = 2026 - house_price_df.data["yr_renovated"]
house_price_df.data.sample(5)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4104   417000.0         3       1.75         1590     11454     1.0
# 10024  455000.0         4       2.50         1320      7000     1.0
# 12684  498000.0         3       2.00         1620      8400     1.0
# 12119  506000.0         3       1.75         2180      7700     1.0
# 8899   653000.0         3       2.25         2800     17300     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 4104            0     0          4      8        1590              0
# 10024           0     0          4      7        1320              0
# 12684           0     0          3      7        1180            440
# 12119           0     0          3      8        1480            700
# 8899            0     0          4      8        1420           1380
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
house_price_df.data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'age', 'renovation_age'],
#       dtype='object')

# %%
selected_features = ['bedrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_basement', 'lat', 'long', 'sqft_lot15', 'age', 'renovation_age']

# %%
house_price_df.data.drop(columns = ["yr_built", "yr_renovated", "sqft_above", "bathrooms", "sqft_living15"], inplace = True)

# %%
experiment = mlflow.get_experiment("1")

# %%
print(f"Name: {experiment.name}")
print(f"Artifact Location: {experiment.artifact_location}")
print(f"Tags: {experiment.tags}")
print(f"Lifecycle_stage: {experiment.lifecycle_stage}")
print(f"Creation timestamp: {experiment.creation_time}")
# Out:
# Name: my-first-experiment
# Artifact Location: /home/zelitosaide/Documents/mlops/mlruns/1
# Tags: {}
# Lifecycle_stage: active
# Creation timestamp: 1780664775064

# %%
mlflow.get_tracking_uri()
# Out:
# 'sqlite:///mlflow.db'

# %%
mlflow.start_run()
mlflow.log_param("nome", "Zelito")
mlflow.log_param("apelido", "Saide")
mlflow.end_run()

# %%
mlflow.start_run(run_name="exploratory_data_analysis")
mlflow.log_param("media", 312)
mlflow.log_param("desvio padrao", 45)
mlflow.end_run()

# %%
mlflow.start_run(run_name="features_as_artifacts")
mlflow.log_artifact("README.md")

# %%
run = mlflow.active_run()
print(f"Active run_id: {run.info.run_id}")
print(f"Active run_name: {run.info.run_name}")
mlflow.end_run()
# Out:
# Active run_id: 5524645073b24b57ab83effc947bac9c
# Active run_name: features_as_artifacts

# %%
with mlflow.start_run(run_name="exploratory data analysis") as current_run:
    mlflow.log_param("using with", "nice")

# %%
run = mlflow.last_active_run()
run.info.run_name
# Out:
# 'exploratory data analysis'

# %%
client = mlflow.MlflowClient()
data = client.get_run(current_run.info.run_id).data
data
# Out:
# <RunData: metrics={}, params={'using with': 'nice'}, tags={'mlflow.runName': 'exploratory data analysis',
#  'mlflow.source.name': 'Untitled.ipynb',
#  'mlflow.source.type': 'NOTEBOOK',
#  'mlflow.user': 'zelitosaide'}>

# %%
experiments = mlflow.search_experiments()
experiments
# Out:
# [<Experiment: artifact_location='/home/zelitosaide/Documents/mlops/mlruns/1', creation_time=1780664775064, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1780664775064, lifecycle_stage='active', name='my-first-experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1780494965718, effective_trace_archival_retention=None, experiment_id='0', last_update_time=1780494965718, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]
